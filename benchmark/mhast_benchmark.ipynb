# %%
# %load_ext autoreload
# %autoreload 2

from utils import box_plot_perf

# %% [markdown]
# ## Quantitative comparison

# %%
file_mhast = "results/mhast/Ovarian_Cancer_full_simulation/4_moco_clusters_30spots_reallike_5mean_5var_mhast.xlsx"
file_deconvplugin_no_adj = "results/mhast/Ovarian_Cancer_full_simulation/deconv-plugin/4_moco_clusters_30spots_reallike_5mean_5var/metrics_cells_best.xlsx"
file_deconvplugin = "results/mhast/Ovarian_Cancer_full_simulation/deconv-plugin/4_moco_clusters_30spots_reallike_5mean_5var/metrics_cells_best_adj.xlsx"

files_info =  [
    (file_mhast, 'Metrics Before', 'random'),
    (file_mhast, 'Metrics After', 'MHAST'),
    (file_deconvplugin_no_adj, 'per_run', 'Deconv-plugin (no adj)'),
    (file_deconvplugin, 'per_run', 'Deconv-plugin')
]

box_plot_perf(files_info, 
              level='cells', 
              title='Real-like dataset', 
              savefig='results/mhast/Ovarian_Cancer_full_simulation/fig/boxplot_benchmark_reallike.png')
# Out:
# Figure saved to results/mhast/Ovarian_Cancer_full_simulation/fig/boxplot_benchmark_reallike.png

# %%
file_mhast = "results/mhast/Ovarian_Cancer_full_simulation/4_moco_clusters_30spots_balanced_5mean_5var_mhast.xlsx"
file_deconvplugin_no_adj = "results/mhast/Ovarian_Cancer_full_simulation/deconv-plugin/4_moco_clusters_30spots_balanced_5mean_5var/metrics_cells_best.xlsx"
file_deconvplugin = "results/mhast/Ovarian_Cancer_full_simulation/deconv-plugin/4_moco_clusters_30spots_balanced_5mean_5var/metrics_cells_best_adj.xlsx"

files_info =  [
    (file_mhast, 'Metrics Before', 'random'),
    (file_mhast, 'Metrics After', 'MHAST'),
    (file_deconvplugin_no_adj, 'per_run', 'Deconv-plugin (no adj)'),
    (file_deconvplugin, 'per_run', 'Deconv-plugin')
]

box_plot_perf(files_info, 
              level='cells', 
              title='Balanced dataset', 
              savefig='results/mhast/Ovarian_Cancer_full_simulation/fig/boxplot_benchmark_balanced.png')
# Out:
# Figure saved to results/mhast/Ovarian_Cancer_full_simulation/fig/boxplot_benchmark_balanced.png
